# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# <H1>"My Jupyter Notebook on IBM Watson Studio" <H1>

# %% [markdown]
# <b>Muhammad Ahmad</b>
# <p>Current Occupation: Accountant</p>
# <p>Desire Occupation: Finance Data Analyst + Programmer</p>

# %% [markdown]
# <p>I am interested in Data Science because it relates to my existing field or Knowledge. Finance is highly impact with data science, therefore, i personally believe that it is right time to learn more about computing tools used in data science.</p>

# %% [markdown]
# <H3>The code below will add the two number and return total using python</H3>

# %%
a = 2
b = 4
a+b
# Out:
# 6

# %% [markdown]
# <i>Cell 6 (rendered as Markdown): Using Markdown or HTML, this cell must include at least 3 of the following: horizontal rule, bulleted list, numbered list, tables, hyperlinks, images, code/syntax highlighting, blocked quotes, strikethrough.</i>

# %% [markdown]
# <b>Number List</b>
#
# <ol>
#   <li>First item</li>
#   <li>Second item</li>
#   <li>Third item</li>
#   <li>Fourth item</li>
# </ol>

# %% [markdown]
# <b>Tables</b>
#
# | Syntax      | Description |
# | ----------- | ----------- |
# | Header      | Title       |
# | Paragraph   | Text        |

# %% [markdown]
# <b>Code</b>
#
# <code>Use `code` in your Markdown file to display code.</code>
